# %% [markdown]
# # Senhorita Pacman (Aprendizado por Reforço)

# %% [markdown]
# ## Dependências Usadas

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
import matplotlib.pyplot as plt
import gymnasium as gym
import numpy as np
import cv2
import numpy as np
from collections import deque
import random
from pathlib import Path

print("TensorFlow:", tf.__version__)
print("Gymnasium:", gym.__version__)
# Out:
# /Users/samuel/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 import gymnasium as gym
#       8 import numpy as np
# ----> 9 import cv2
#      10 import numpy as np
#      11 from collections import deque
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ### Configuração do Ambiente (GPU M4)

# %%
# %pip install tensorflow-metal

# %%
gpus = tf.config.list_physical_devices("GPU")

if gpus:
    print("GPU encontrada:")
    print(gpus)
else:
    print("Nenhuma GPU encontrada.")
    
env = gym.make("ALE/MsPacman-v5")

obs, info = env.reset()

print("Ambiente iniciado com sucesso.")
print(obs.shape)
# Out:
# GPU encontrada:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ---------------------------------------------------------------------------
# NamespaceNotFound                         Traceback (most recent call last)
# Cell In[2], line 9
#       6 else:
#       7     print("Nenhuma GPU encontrada.")
# ----> 9 env = gym.make("ALE/MsPacman-v5")
#      11 obs, info = env.reset()
#      13 print("Ambiente iniciado com sucesso.")
#
# File ~/Library/Python/3.9/lib/python/site-packages/gymnasium/envs/registration.py:689, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     686     assert isinstance(id, str)
#     688     # The environment name can include an unloaded module in "module:env_name" style
# --> 689     env_spec = _find_spec(id)
#     691 assert isinstance(env_spec, EnvSpec)
#     693 # Update the env spec kwargs with the `make` kwargs
#
# ...

# %% [markdown]
# ## Construção do Modelo

# %% [markdown]
# ### Funções Auxiliares

# %%
def preprocess(frame):
    frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    frame = cv2.resize(
        frame,
        (84, 84)
    )
    frame = frame / 255.0
    return frame

class ReplayBuffer:
    def __init__(self, capacity=100000):
        self.buffer = deque(maxlen=capacity)

    def add(self, state, action, reward, next_state, done):
        self.buffer.append(
            (state, action, reward, next_state, done)
        )

    def sample(self, batch_size):
        return random.sample(
            self.buffer,
            batch_size
        )

    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# ### Modelo DQN

# %%
def create_dqn(action_space):
    model = Sequential([
        Conv2D(32, 8, strides=4, activation="relu", input_shape=(84,84,1)),
        Conv2D(64, 4, strides=2, activation="relu"),
        Conv2D(64, 3, activation="relu"),
        Flatten(),
        Dense(512, activation="relu"),
        Dense(action_space, activation="linear")
    ])

    return model

# %%
env = gym.make("ALE/MsPacman-v5")

model = create_dqn(
    env.action_space.n
)

model.summary()

GAMMA = 0.99
EPSILON = 1.0
EPSILON_MIN = 0.1
EPSILON_DECAY = 0.995
BATCH_SIZE = 64
EPISODES = 500

optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.00025
)

replay_buffer = ReplayBuffer()
rewards_history = []

# %% [markdown]
# ### Loop de Treinamento

# %%
for episode in range(EPISODES):
    state, info = env.reset()
    total_reward = 0
    done = False

    while not done:
        # ação
        # ambiente
        # replay buffer
        # treinamento
        pass

    rewards_history.append(
        total_reward
    )

# %% [markdown]
# ## Avaliação do Modelo

# %%
plt.plot(rewards_history)
plt.xlabel("Episódio")
plt.ylabel("Reward")
plt.title("Treinamento")
plt.show()

print(
    np.mean(
        rewards_history[-50:]
    )
)

# %% [markdown]
# ## Exportação do Modelo

# %%
Path("../modelos/felipe_samuel").mkdir(exist_ok=True)

model.save("../modelos/felipe_samuel/dqn_mspacman.keras")
print("Modelo salvo.")
